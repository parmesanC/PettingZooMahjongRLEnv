# %%
from src.mahjong_rl.core.constants import ActionType
from src.mahjong_rl.core.PlayerData import Meld

# 重新创建列表
melds = [Meld(action_type=ActionType.CHOW_LEFT, tiles=[4, 5, 6])]
print(f"Value: {melds[0].action_type}, Type: {type(melds[0].action_type)}")
print(melds[0].action_type in {ActionType.CHOW_LEFT, ActionType.CHOW_MIDDLE, ActionType.CHOW_RIGHT})
for meld in melds:
    print(meld.is_chow)
# Out:
# Value: ActionType.CHOW_LEFT, Type: <enum 'ActionType'>
# True
# True
